# %% [markdown]
# ### Images

# %%
from clearml import Dataset

DATASET_NAME  = "fatigue-raw-frames-v2"
DATASET_PROJECT = "FatigueSense"

# Get latest version
parent = Dataset.get(
    dataset_name=DATASET_NAME,
    dataset_project=DATASET_PROJECT,
)

# Create new dataset version, with the previous version as parent
ds_new = Dataset.create(
    dataset_name=DATASET_NAME,
    dataset_project=DATASET_PROJECT,
    parent_datasets=[parent.id],
)

# UPLOAD NEW FILES HERE
# Note: Set the dataset_path to the name of your video. For the sake of convention, we will use the naming convention
# vid_XXX, where XXX is the three digit video number (e.g. vid_001, vid_002, etc.).
# CURRENT: vid_002, next vid_003. Update this line after updating.
# Upload the metadata files (data.yaml and train.txt) to the metadata folder, and the label files to the vid_XXX folder.

dataset_folder = "vid_004" # Update this line after updating.
# Images
ds_new.add_files(
    path="../dataset_3/images",
    dataset_path=dataset_folder,
)

# Start upload
ds_new.upload(show_progress=True)
ds_new.finalize()
# Out:
# ClearML results page: https://app.clear.ml/projects/14ea2657dfe14ee482acc6d30aa1bb25/experiments/259d8426c9a64828accb1741fd61c256/output/log
# ClearML dataset page: https://app.clear.ml/datasets/simple/14ea2657dfe14ee482acc6d30aa1bb25/experiments/259d8426c9a64828accb1741fd61c256
# Generating SHA2 hash for 300 files
# 100%|██████████| 300/300 [00:00<00:00, 2233.94it/s]
# Hash generation completed
# Uploading dataset changes (300 files compressed to 186.86 MiB) to https://files.clear.ml
# █████████████████████████████ 100% | 186.86/186.86 MB [11:20<00:00,  3.64s/MB]:
# File compression and upload completed: total size 186.86 MiB, 1 chunk(s) stored (average size 186.86 MiB)
# True

# %% [markdown]
# ### Labels

# %%
from clearml import Dataset

DATASET_NAME  = "fatigue-region-labels-v2"
DATASET_PROJECT = "FatigueSense"

# Get latest version
parent = Dataset.get(
    dataset_name=DATASET_NAME,
    dataset_project=DATASET_PROJECT,
)

# Create new dataset version, with the previous version as parent
ds_new = Dataset.create(
    dataset_name=DATASET_NAME,
    dataset_project=DATASET_PROJECT,
    parent_datasets=["a960a05b7b0c4c9da1cb8cbff790bbad"],
)

# UPLOAD NEW FILES HERE
# Note: Set the dataset_path to the name of your video. For the sake of convention, we will use the naming convention
# vid_XXX, where XXX is the three digit video number (e.g. vid_001, vid_002, etc.).
# CURRENT: vid_003, next vid_004. Update this line after updating.
# Upload the metadata files (data.yaml and train.txt) to the metadata folder, and the label files to the vid_XXX folder.
folder = "vid_004"

# Labels
ds_new.add_files(
    path="../dataset_3/labels",
    dataset_path=folder,
)
# Data.yaml
ds_new.add_files(
    path="../dataset_3/data.yaml",
    dataset_path=f"{folder}/metadata",
)
# Train.txt
ds_new.add_files(
    path="../dataset_3/train.txt",
    dataset_path=f"{folder}/metadata",
)

# Start upload
ds_new.upload(show_progress=True)
ds_new.finalize()
# Out:
# ClearML results page: https://app.clear.ml/projects/8366e6b8f52f4ccc9d92386851711371/experiments/0ab9f1a33c80424da2a2a2beb9c36995/output/log
# ClearML dataset page: https://app.clear.ml/datasets/simple/8366e6b8f52f4ccc9d92386851711371/experiments/0ab9f1a33c80424da2a2a2beb9c36995
# Generating SHA2 hash for 300 files
# 100%|██████████| 300/300 [00:00<00:00, 7879.54it/s]
# Hash generation completed
# Uploading dataset changes (301 files compressed to 84.57 KiB) to https://files.clear.ml
# File compression and upload completed: total size 84.57 KiB, 1 chunk(s) stored (average size 84.57 KiB)
# True
